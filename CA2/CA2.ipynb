# %% [markdown]
# # CA2 - Supervised machine learning classification pipeline - applied to medical data

# %% [markdown]
# ### Important information
#
# - Do __not__ use scikit-learn (`sklearn`) or any other high-level machine learning library for this CA
# - Explain your code and reasoning in markdown cells or code comments
# - Label all graphs and charts if applicable
# - If you use code from the internet, make sure to reference it and explain it in your own words
# - If you use additional function arguments, make sure to explain them in your own words
# - Use the classes `Perceptron`, `Adaline` and `Logistic Regression` from the library `mlxtend` as classifiers (`from mlxtend.classifier import Perceptron, Adaline, LogisticRegression`). _Always_ use the argument `minibatches=1` when instantiating an `Adaline` or `LogisticRegression` object. This makes the model use the gradient descent algorithm for training. Always use the `random_seed=42` argument when instantiating the classifiers. This will make your results reproducible.
# - You can use any plotting library you want (e.g. `matplotlib`, `seaborn`, `plotly`, etc.)
# - Use explanatory variable names (e.g. `X_train` and `X_train_scaled` for the training data before and after scaling, respectively)
# - The dataset is provided in the file `fetal_health.csv` in the `assets` folder
#
# ### Additional clues
#
# - Use the `pandas` library for initial data inspection and preprocessing
# - Before training the classifiers, convert the data to raw `numpy` arrays
# - For Part IV, you are aiming to create a plot that looks similar to this:
# <img src="./assets/example_output.png" width="300">
#
# ### Additional information
#
# - Feel free to create additional code or markdown cells if you think it will help you explain your reasoning or structure your code (you don't have to).

# %% [markdown]
# ## Part I: Data loading and data exploration

# %% [markdown]
# ### Import necessary libraries/modules:

# %%
# Insert your code below
# ======================
from mlxtend.classifier import Perceptron, Adaline, LogisticRegression
import pandas as pd
import seaborn as sns 
sns.set_style('darkgrid')
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading and exploring data
#
# 1. Load the dataset `fetal_health.csv` with `pandas`. Use the first column as the row index.
# 2. Check for missing data, report on your finding and remove samples with missing data, if you find any.
# 3. Display the raw data with appropriate plots/outputs and inspect it. Describe the distributions of the values of feature `"baseline value"`, `"accelerations"`, and the target variable `"fetal_health"`.
# 4. Will it be beneficial to scale the data? Why or why not?
# 5. Is the data linearly separable using a combination of any two pairs of features? Can we expect an accuracy close to 100% from a linear classifier?

# %%
# Insert your code below
# ======================
data = pd.read_csv("assets/fetal_health.csv", index_col=0)
data.head(25)
# Out:
#       baseline value  accelerations  prolongued_decelerations  \
# 1584           132.0          0.000                       0.0
# 942            136.0          0.003                       0.0
# 1376           121.0          0.006                       0.0
# 169            116.0          0.001                       0.0
# 1293           115.0          0.006                       0.0
# 1271           119.0          0.000                       0.0
# 1242           115.0          0.000                       0.0
# 908            146.0          0.008                       0.0
# 934            126.0          0.003                       0.0
# 1482           132.0          0.000                       0.0
# 924            122.0          0.005                       0.0
# 1050           125.0          0.007                       0.0
# 956            136.0          0.000                       0.0
# 2084           128.0          0.001                       0.0
# 246            128.0          0.007                       0.0
# 692            133.0          0.008                       0.0
# 1266           119.0          0.003                       0.0
# 425            156.0          0.000                       0.0
# 1480           149.0          0.010                       0.0
# 788            123.0          0.003                       0.0
# 284            128.0          0.007                       0.0
# 1305           138.0          0.000                       0.0
# 1077           134.0          0.002                       0.0
# 58             148.0          0.000                       0.0
# 1593           134.0          0.000                       0.0
#
#       abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 1584                             35.0                                   1.3
# 942                              54.0                                   0.7
# 1376                             24.0                                   1.7
# 169                              46.0                                   0.7
# 1293                             19.0                                   1.7
# 1271                             27.0                                   1.2
# 1242                             20.0                                   1.7
# 908                              28.0                                   1.3
# 934                              25.0                                   1.8
# 1482                             47.0                                   0.7
# 924                              31.0                                   1.2
# 1050                             26.0                                   1.3
# 956                              32.0                                   1.3
# 2084                             76.0                                   1.7
# 246                              48.0                                   1.0
# 692                              24.0                                   2.1
# 1266                             25.0                                   1.3
# 425                              53.0                                   0.6
# 1480                             35.0                                   1.0
# 788                              52.0                                   0.8
# 284                              44.0                                   1.1
# 1305                             34.0                                   1.0
# 1077                             26.0                                   1.8
# 58                               41.0                                   0.8
# 1593                             20.0                                   2.1
#
#       percentage_of_time_with_abnormal_long_term_variability  histogram_mean  \
# 1584                                                0.0                135.0
# 942                                                15.0                141.0
# 1376                                                0.0                121.0
# 169                                                39.0                120.0
# 1293                                                0.0                121.0
# 1271                                                0.0                120.0
# 1242                                                0.0                118.0
# 908                                                 1.0                154.0
# 934                                                 0.0                130.0
# 1482                                                1.0                134.0
# 924                                                 0.0                130.0
# 1050                                                0.0                133.0
# 956                                                 0.0                133.0
# 2084                                               25.0                127.0
# 246                                                 0.0                137.0
# 692                                                 0.0                128.0
# 1266                                                0.0                123.0
# 425                                                 6.0                159.0
# 1480                                                0.0                166.0
# 788                                                 3.0                128.0
# 284                                                 0.0                136.0
# 1305                                                7.0                142.0
# 1077                                               10.0                133.0
# 58                                                 29.0                153.0
# 1593                                                0.0                117.0
#
#       histogram_variance  fetal_health
# 1584                 9.0             0
# 942                  8.0             0
# 1376                25.0             0
# 169                  1.0             0
# 1293                 9.0             0
# 1271                 1.0             0
# 1242                 4.0             0
# 908                  6.0             0
# 934                 12.0             0
# 1482                 2.0             0
# 924                 12.0             0
# 1050                11.0             0
# 956                 19.0             0
# 2084                 1.0             0
# 246                  6.0             0
# 692                 69.0             0
# 1266                 5.0             0
# 425                  2.0             0
# 1480                 5.0             0
# 788                  5.0             0
# 284                  5.0             0
# 1305                10.0             0
# 1077                40.0             0
# 58                   0.0             0
# 1593                63.0             0

# %%
# Checking for null values and summing up the total null values for each column
missing_values = data.isnull().sum()
missing_values
# The results from the isnull.sum tell us that there are no missing samples in the dataset
# Out:
# baseline value                                            0
# accelerations                                             0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# histogram_mean                                            0
# histogram_variance                                        0
# fetal_health                                              0
# dtype: int64

# %%
# Start with violin plots for baseline value, abnormal short term variability and accelerations

fig, axis = plt.subplots(1, 3, figsize=(12, 4))

for idx, var in enumerate(["baseline value", "accelerations", "abnormal_short_term_variability"]):
    sns.violinplot(data=data, y=var, ax=axis[idx])
    axis[idx].set_title(var)
    
fig.tight_layout()
plt.show()

# %%
# Histogram for histogram mean and histogram variance med 10 bins

fig, axes = plt.subplots(1, 2, figsize=(8, 4))

for idx, var in enumerate(["histogram_mean", "histogram_variance"]):
    sns.histplot(data=data[var], ax=axes[idx], bins=10)
    
fig.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# boxplot for mean value of short term variability og percentage of time with abnormal long term variability

fig, axis = plt.subplots(1, 2, figsize=(8, 4))

for idx, var in enumerate(["mean_value_of_short_term_variability", "percentage_of_time_with_abnormal_long_term_variability"]):
    sns.boxplot(data=data[var], ax=axis[idx])
    axis[idx].set_title(var, fontsize=9)

fig.tight_layout()
plt.plot()
# Out:
# []

# %%
# Histogram for å vise antallet i fetal health variable 
fig, axes = plt.subplots(1,1,figsize=(4,4))
sns.histplot(data=data, x="fetal_health", ax=axes, discrete=True)
axes.set_title("Distribution of the fetal health variable")

for p in axes.patches:
    height = p.get_height()
    position_x = p.get_x() + p.get_width() / 2
    axes.text(position_x, height, f'{height}', ha="center", va="bottom", fontsize=10)

plt.xticks([0, 1])
plt.show()

# %%
# Lage et pairplot av alle variablene som er i datasettet for å bruke videre for å se på om dataen er lineær separabel
sns.pairplot(data=data, hue="fetal_health")

# %% [markdown]
# ## Description of the distributions
#
#
# * `"baseline value"`: Looks to be almost following a normal distribution, shown in both the pairplot and violin plot
# * `"accelerations"`: Looks heavily skewed to one side of the distribution, shown both in the pairplot and violin plot of accelerations
# * `"fetal_health"`: Only two choices, but a higher count for the value 0 than one, shown in the distribution of fetal health variable plot

# %% [markdown]
# ## Scaling or not
# It would be beneficial to scale the data in this dataset. Some reasons for this are
# 1. There are large differences in magnitudes in the data, meaning that some features have very high values, while some have very low which significantly impacts the efficiency of a machine learning model.
# 2. Skewed distributions like `"histogram_variance"` and others can be scaled to be more central making them more uniform and easier to work with when it comes to using it with other variables
# 3. Improvement of the model convergence

# %% [markdown]
# ## Part II: Train/Test Split
#
# Divide your dataset into training and testing subsets. Follow these steps to create the split:
#
# 1. **Divide the dataset into two data sets, each data set only contains samples of either class 0 or class 1:**
# - Create a DataFrame `df_0` containing all data with `"fetal_health"` equal to 0.
# - Create a DataFrame `df_1` containing all data with `"fetal_health"` equal to 1.
#
# 2. **Split into training and test set by randomly sampling entries from the data frames:**
# - Create a DataFrame `df_0_train` containing by sampling `75%` of the entries from `df_0` (use the `sample` method of the data frame, fix the `random_state` to `42`).
# - Create a DataFrame `df_1_train` using the same approach with `df_1`.
# - Create a DataFrame `df_0_test` containing the remaining entries of `df_0` (use `df_0.drop(df_0_train.index)` to drop all entries except the previously extracted ones).
# - Create a DataFrame `df_1_test` using the same approach with `df_1`.
#
# 3. **Merge the datasets split by classes back together:**
# - Create a DataFrame `df_train` containing all entries from `df_0_train` and `df_1_train`. (Hint: use the `concat` method you know from CA1)
# - Create a DataFrame `df_test` containing all entries from the two test sets.
#
# 4. **Create the following data frames from these splits:**
# - `X_train`: Contains all columns of `df_train` except for the target feature `"fetal_health"`
# - `X_test`: Contains all columns of `df_test` except for the target feature `"fetal_health"`
# - `y_train`: Contains only the target feature `"fetal_health"` for all samples in the training set
# - `y_test`: Contains only the target feature `"fetal_health"` for all samples in the test set
#
# 5. **Check that your sets have the expected sizes/shape by printing number of rows and colums ("shape") of the data sets.**
# - (Sanity check: there should be 8 features, almost 1000 samples in the training set and slightly more than 300 samples in the test set.)
#
#
# 6. **Explain the purpose of this slightly complicated procedure. Why did we first split into the two classes? Why did we then split into a training and a testing set?**
#
#
# 7. **What is the share (in percent) of samples with class 0 label in test and training set, and in the intial data set?**

# %%
# Insert your code below
# ======================

#Creating two datasets for fetal health 0 and 1
df_0 = data[data["fetal_health"] == 0]
df_1 = data[data["fetal_health"] == 1]

#Creating a training set for the data frames, using random sampling
df_0_train = df_0.sample(frac=0.75, random_state=42)
df_1_train = df_1.sample(frac=0.75, random_state=42)

#Creating a test set containing the remaining entries of df_0 and df_1
df_0_test = df_0.drop(df_0_train.index)
df_1_test = df_1.drop(df_1_train.index)

#Creating a dataframe for training and testing, containing data for fetal health 0 and 1
df_train = pd.concat([df_0_train, df_1_train])
df_test = pd.concat([df_0_test, df_1_test])

#Splitting the data into X and y where X contains all columns except fetal_health and y contains only fetal_health 
X_train = df_train.drop(columns="fetal_health")
X_test = df_test.drop(columns="fetal_health")

y_train = df_train["fetal_health"]
y_test = df_test["fetal_health"]

#Checking if the sets has expected size/shape
print("Shape of datasets:\n", X_train.shape, X_test.shape, "\n")

#Checking percentage of fetal health 0 in test set, training set and initial dataset
print("Test set:\n", df_test["fetal_health"].value_counts(normalize=True) * 100, "\n")
print("Training set:\n", df_train["fetal_health"].value_counts(normalize=True) * 100, "\n")
print("Inintal set:\n", data["fetal_health"].value_counts(normalize=True) * 100)
# Out:
# Shape of datasets:
#  (967, 8) (323, 8)
#
# Test set:
#  fetal_health
# 0    63.77709
# 1    36.22291
# Name: proportion, dtype: float64
#
# Training set:
#  fetal_health
# 0    63.805584
# 1    36.194416
# Name: proportion, dtype: float64
#
# Inintal set:
#  fetal_health
# 0    63.79845
# 1    36.20155
# Name: proportion, dtype: float64

# %% [markdown]
# ## Purpose of procedure
# ### Why did we split into the two classes?
# * We did this to separate the datasets so that we have one dataset where fetal health is 0 and one where fetal health is 1. The benefit of doing this is to see what trends may lead to the two outcomes.
#
# ### Why did we then split into a training and a testing set?
# * The training set will be used to train the data and see different trends, while the test set will be used to see if these trends actually are true.

# %% [markdown]
# ### Convert data to numpy arrays and shuffle the training data
#
# Many machine learning models (including those you will work with later in the assignment) will not accept DataFrames as input. Instead, they will only work if you pass numpy arrays containing the data.
# Here, we convert the DataFrames `X_train`, `X_test`, `y_train`, and `y_test` to numpy arrays `X_train`, `X_test`, `y_train`, and `y_test`.
#
# Moreover we shuffle the training data. This is important because the training data is currently ordered by class. In Part IV, we use the first n samples from the training set to train the classifiers. If we did not shuffle the data, the classifiers would only be trained on samples of class 0.
#
# Nothing to be done here, just execute the cell.

# %%
# convert to numpy arrays
X_train = X_train.to_numpy()
X_test = X_test.to_numpy()
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# shuffle training data
np.random.seed(42) # for reproducibility
shuffle_index = np.random.permutation(len(X_train)) # generate random indices
X_train, y_train = X_train[shuffle_index], y_train[shuffle_index] # shuffle data by applying reordering with the random indices
# Out:
# (967,)

# %% [markdown]
# ## Part III: Scaling the data
#
# 1. Standardize the training _and_ test data so that each feature has a mean of 0 and a standard deviation of 1.
# 2. Check that the scaling was successful
#     - by printing the mean and standard deviation of each feature in the scaled training set
#     - by putting the scaled training set into a DataFrame and make a violin plot of the data
#
# __Hint:__ use the `axis` argument to calculate mean and standard deviation column-wise.
#
# __Important:__ Avoid data leakage!
#
# __More hints:__
#
# 1. For each column, subtract the mean $(\mu)$ of each column from each value in the column
# 2. Divide the result by the standard deviation $(\sigma)$ of the column
#
# (You saw how to do both operations in the lecture. If you don't remember, you can look it up in Canvas files.)
#
# Mathematically (in case this is useful for you), this transformation can be represented for each column as follows:
#
# $$ X_\text{scaled} = \frac{(X - \mu)}{\sigma} $$
#
# where:
# - $(X_\text{scaled})$ are the new, transformed column values (a column-vector)
# - $(X)$ is the original values
# - $(\mu)$ is the mean of the column
# - $(\sigma)$ is the standard deviation of the column

# %%
# Insert your code below
# ======================

X_train_mean = np.mean(df_train, axis=0)
X_train_std = np.std(df_train, axis=0, ddof=1)
X_train_scaled = (df_train - X_train_mean) / X_train_std

print(np.mean(X_train_scaled.to_numpy(), axis=0))
print(np.std(X_train_scaled.to_numpy(), axis=0))


X_test_mean = np.mean(df_train, axis=0)
X_test_std = np.std(df_train, axis=0, ddof=1)
X_test_scaled = (df_test - X_test_mean) / X_test_std
    
print(np.mean(X_test_scaled.to_numpy(), axis=0))
print(np.std(X_test_scaled.to_numpy(), axis=0))

# Data leakage occurs when information from the test set is used during training.
# Therefore we only apply mean and standard deviation from the training dataset to scale both datasets, to keep test data statistics unseen
# Out:
# [-1.02870717e-16  0.00000000e+00  0.00000000e+00  2.35133067e-16
#  -7.34790833e-17 -2.93916333e-17 -3.30655875e-16 -2.20437250e-17
#  -5.87832667e-17]
# [0.9994828 0.9994828 0.9994828 0.9994828 0.9994828 0.9994828 0.9994828
#  0.9994828 0.9994828]
# [-0.02278484  0.10517582  0.06832144  0.00942429  0.018526   -0.05581759
#   0.0135212  -0.02609709  0.00059263]
# [0.94550854 1.08350973 1.16912371 0.96831631 1.02350704 0.8873325
#  0.97185078 0.90821045 0.99965286]

# %% [markdown]
# ## Part IV: Training and evaluation with different dataset sizes and training times
#
# Often, a larger dataset size will yield better model performance. (As we will learn later, this usually prevents overfitting and increases the generalization capability of the trained model.)
# However, collecting data is usually rather expensive.
#
# In this part of the exercise, you will investigate
#
# - how the model performance changes with varying dataset size
# - how the model performance changes with varying numbers of epochs/iterations of the optimizer/solver (increasing training time).
#
# For this task (Part IV), use the `Adaline`, `Perceptron`, and `LogisticRegression` classifier from the `mlxtend` library. All use the gradient descent (GD) algorithm for training.
#
# __Important__: Use a learning rate of `1e-4` (`0.0001`) for all classifiers, and use the argument `minibatches=1` when initializing `Adaline` and `LogisticRegression` classifier (this will make sure it uses GD). For all three classifiers, pass `random_seed=42` when initializing the classifier to ensure reproducibility of the results.
#
# ### Model training
#
# Train the model models using progressively larger subsets of your dataset, specifically: first 50 rows, first 100 rows, first 150 rows, ..., first 650 rows, first 700 rows (in total $14$ different variants).
#
# For each number of rows train the model with progressively larger number of epochs: 2, 7, 12, 17, ..., 87, 92, 97 (in total $20$ different model variants).
#
# The resulting $14 \times 20 = 280$ models obtained from the different combinations of subsets and number of epochs. An output of the training process could look like this:
#
# ```
# Model (1) Train a model with first 50 rows of data for 2 epochs
# Model (2) Train a model with first 50 rows of data for 7 epochs
# Model (3) Train a model with first 50 rows of data for 12 epochs
# ...
# Model (21) Train a model with first 100 rows of data for 2 epochs
# Model (22) Train a model with first 100 rows of data for 7 epochs
# ...
# Model (279) Train a model with first 700 rows of data for 92 epochs
# Model (280) Train a model with first 700 rows of data for 97 epochs
# ```
#
# ### Model evaluation
#
# For each of the $280$ models, calculate the __accuracy on the test set__ (do __not__ use the score method but compute accuracy yourself).
# Store the results in the provided 2D numpy array (it has $14$ rows and $20$ columns).
# The rows of the array correspond to the different dataset sizes, and the columns correspond to the different numbers of epochs.
#
# ### Tasks
# 1. Train the $280$ Adaline classifiers as mentioned above and calculate the accuracy for each of the $280$ variants.
# 2. Generalize your code so that is doing the same procedure for all three classifiers: `Perceptron`, `Adaline`, and `LogisticRegression` after each other. Store the result for all classifiers. You can for example use an array of shape $3\times14\times20$ to store the accuracies of the three classifiers.
#
# Note that executing the cells will take some time (but on most systems it should not be more than 5 minutes).

# %%
# Train and evaluate all model variants
# Insert your code below
# ======================

model_types = ["Perceptron", "Adaline", "LogisticRegression"]
row_limit_start = 50
accuracy_matrix = np.zeros((3, 14, 20))

for model_idx, model_type in enumerate(model_types):
    row_limit = row_limit_start
    model_num = 1
    
    for i in range(14):
        epoch_limit = 2

        for j in range(20):
            if model_type == "Perceptron":
                model = Perceptron(epochs=epoch_limit, eta=0.0001, random_seed=42)
            elif model_type == "Adaline":
                model = Adaline(epochs=epoch_limit, eta=0.0001, random_seed=42, minibatches=1)
            elif model_type == "LogisticRegression":
                model = LogisticRegression(epochs=epoch_limit, eta=0.0001, random_seed=42, minibatches=1)
            else:
                print("Model types not valid! try again...")
                
            model.fit(X_train_scaled.to_numpy()[:row_limit], y_train[:row_limit])
            y_pred = model.predict(X_test_scaled.to_numpy())
            accuracy = np.mean(y_pred == y_test)
            
            accuracy_matrix[model_idx, i, j] = accuracy
            
            print(f"Model ({model_num}) - {model_type.capitalize()} | Train with {row_limit} rows for {epoch_limit} epochs - Accuracy: {accuracy:.2f}")
            
            epoch_limit += 5
            model_num += 1  

        row_limit += 50
        
print("\nFinal Accuracy Matrix (3x14x20):")
print(accuracy_matrix)
# Out:
# Model (1) - Perceptron | Train with 50 rows for 2 epochs - Accuracy: 0.69
# Model (2) - Perceptron | Train with 50 rows for 7 epochs - Accuracy: 0.51
# Model (3) - Perceptron | Train with 50 rows for 12 epochs - Accuracy: 0.39
# Model (4) - Perceptron | Train with 50 rows for 17 epochs - Accuracy: 0.49
# Model (5) - Perceptron | Train with 50 rows for 22 epochs - Accuracy: 0.45
# Model (6) - Perceptron | Train with 50 rows for 27 epochs - Accuracy: 0.33
# Model (7) - Perceptron | Train with 50 rows for 32 epochs - Accuracy: 0.43
# Model (8) - Perceptron | Train with 50 rows for 37 epochs - Accuracy: 0.42
# Model (9) - Perceptron | Train with 50 rows for 42 epochs - Accuracy: 0.43
# Model (10) - Perceptron | Train with 50 rows for 47 epochs - Accuracy: 0.25
# Model (11) - Perceptron | Train with 50 rows for 52 epochs - Accuracy: 0.39
# Model (12) - Perceptron | Train with 50 rows for 57 epochs - Accuracy: 0.48
# Model (13) - Perceptron | Train with 50 rows for 62 epochs - Accuracy: 0.37
# Model (14) - Perceptron | Train with 50 rows for 67 epochs - Accuracy: 0.15
# Model (15) - Perceptron | Train with 50 rows for 72 epochs - Accuracy: 0.53
# Model (16) - Perceptron | Train with 50 rows for 77 epochs - Accuracy: 0.25
# Model (17) - Perceptron | Train with 50 rows for 82 epochs - Accuracy: 0.37
# Model (18) - Perceptron | Train with 50 rows for 87 epochs - Accuracy: 0.31
# Model (19) - Perceptron | Train with 50 rows for 92 epochs - Accuracy: 0.19
# Model (20) - Perceptron | Train with 50 rows for 97 epochs - Accuracy: 0.40
# Model (21) - Perceptron | Train with 100 rows for 2 epochs - Accuracy: 0.48
# Model (22) - Perceptron | Train with 100 rows for 7 epochs - Accuracy: 0.37
# Model (23) - Perceptron | Train with 100 rows for 12 epochs - Accuracy: 0.24
# Model (24) - Perceptron | Train with 100 rows for 17 epochs - Accuracy: 0.58
# Model (25) - Perceptron | Train with 100 rows for 22 epochs - Accuracy: 0.28
# Model (26) - Perceptron | Train with 100 rows for 27 epochs - Accuracy: 0.11
# Model (27) - Perceptron | Train with 100 rows for 32 epochs - Accuracy: 0.30
# Model (28) - Perceptron | Train with 100 rows for 37 epochs - Accuracy: 0.30
# Model (29) - Perceptron | Train with 100 rows for 42 epochs - Accuracy: 0.41
# Model (30) - Perceptron | Train with 100 rows for 47 epochs - Accuracy: 0.29
# Model (31) - Perceptron | Train with 100 rows for 52 epochs - Accuracy: 0.53
# Model (32) - Perceptron | Train with 100 rows for 57 epochs - Accuracy: 0.35
# Model (33) - Perceptron | Train with 100 rows for 62 epochs - Accuracy: 0.27
# Model (34) - Perceptron | Train with 100 rows for 67 epochs - Accuracy: 0.48
# Model (35) - Perceptron | Train with 100 rows for 72 epochs - Accuracy: 0.40
# Model (36) - Perceptron | Train with 100 rows for 77 epochs - Accuracy: 0.50
# Model (37) - Perceptron | Train with 100 rows for 82 epochs - Accuracy: 0.10
# Model (38) - Perceptron | Train with 100 rows for 87 epochs - Accuracy: 0.59
# Model (39) - Perceptron | Train with 100 rows for 92 epochs - Accuracy: 0.57
# Model (40) - Perceptron | Train with 100 rows for 97 epochs - Accuracy: 0.38
# Model (41) - Perceptron | Train with 150 rows for 2 epochs - Accuracy: 0.42
# Model (42) - Perceptron | Train with 150 rows for 7 epochs - Accuracy: 0.41
# Model (43) - Perceptron | Train with 150 rows for 12 epochs - Accuracy: 0.49
# Model (44) - Perceptron | Train with 150 rows for 17 epochs - Accuracy: 0.35
# Model (45) - Perceptron | Train with 150 rows for 22 epochs - Accuracy: 0.31
# Model (46) - Perceptron | Train with 150 rows for 27 epochs - Accuracy: 0.53
# Model (47) - Perceptron | Train with 150 rows for 32 epochs - Accuracy: 0.37
# Model (48) - Perceptron | Train with 150 rows for 37 epochs - Accuracy: 0.41
# Model (49) - Perceptron | Train with 150 rows for 42 epochs - Accuracy: 0.11
# Model (50) - Perceptron | Train with 150 rows for 47 epochs - Accuracy: 0.46
# Model (51) - Perceptron | Train with 150 rows for 52 epochs - Accuracy: 0.37
# Model (52) - Perceptron | Train with 150 rows for 57 epochs - Accuracy: 0.21
# Model (53) - Perceptron | Train with 150 rows for 62 epochs - Accuracy: 0.22
# Model (54) - Perceptron | Train with 150 rows for 67 epochs - Accuracy: 0.40
# Model (55) - Perceptron | Train with 150 rows for 72 epochs - Accuracy: 0.46
# Model (56) - Perceptron | Train with 150 rows for 77 epochs - Accuracy: 0.40
# Model (57) - Perceptron | Train with 150 rows for 82 epochs - Accuracy: 0.22
# Model (58) - Perceptron | Train with 150 rows for 87 epochs - Accuracy: 0.28
# Model (59) - Perceptron | Train with 150 rows for 92 epochs - Accuracy: 0.33
# Model (60) - Perceptron | Train with 150 rows for 97 epochs - Accuracy: 0.28
# Model (61) - Perceptron | Train with 200 rows for 2 epochs - Accuracy: 0.41
# Model (62) - Perceptron | Train with 200 rows for 7 epochs - Accuracy: 0.41
# Model (63) - Perceptron | Train with 200 rows for 12 epochs - Accuracy: 0.13
# Model (64) - Perceptron | Train with 200 rows for 17 epochs - Accuracy: 0.28
# Model (65) - Perceptron | Train with 200 rows for 22 epochs - Accuracy: 0.13
# Model (66) - Perceptron | Train with 200 rows for 27 epochs - Accuracy: 0.42
# Model (67) - Perceptron | Train with 200 rows for 32 epochs - Accuracy: 0.53
# Model (68) - Perceptron | Train with 200 rows for 37 epochs - Accuracy: 0.21
# Model (69) - Perceptron | Train with 200 rows for 42 epochs - Accuracy: 0.37
# Model (70) - Perceptron | Train with 200 rows for 47 epochs - Accuracy: 0.34
# Model (71) - Perceptron | Train with 200 rows for 52 epochs - Accuracy: 0.42
# Model (72) - Perceptron | Train with 200 rows for 57 epochs - Accuracy: 0.27
# Model (73) - Perceptron | Train with 200 rows for 62 epochs - Accuracy: 0.44
# Model (74) - Perceptron | Train with 200 rows for 67 epochs - Accuracy: 0.62
# Model (75) - Perceptron | Train with 200 rows for 72 epochs - Accuracy: 0.56
# Model (76) - Perceptron | Train with 200 rows for 77 epochs - Accuracy: 0.22
# Model (77) - Perceptron | Train with 200 rows for 82 epochs - Accuracy: 0.52
# Model (78) - Perceptron | Train with 200 rows for 87 epochs - Accuracy: 0.35
# Model (79) - Perceptron | Train with 200 rows for 92 epochs - Accuracy: 0.42
# Model (80) - Perceptron | Train with 200 rows for 97 epochs - Accuracy: 0.37
# Model (81) - Perceptron | Train with 250 rows for 2 epochs - Accuracy: 0.49
# Model (82) - Perceptron | Train with 250 rows for 7 epochs - Accuracy: 0.38
# Model (83) - Perceptron | Train with 250 rows for 12 epochs - Accuracy: 0.51
# Model (84) - Perceptron | Train with 250 rows for 17 epochs - Accuracy: 0.35
# Model (85) - Perceptron | Train with 250 rows for 22 epochs - Accuracy: 0.47
# Model (86) - Perceptron | Train with 250 rows for 27 epochs - Accuracy: 0.32
# Model (87) - Perceptron | Train with 250 rows for 32 epochs - Accuracy: 0.47
# Model (88) - Perceptron | Train with 250 rows for 37 epochs - Accuracy: 0.37
# Model (89) - Perceptron | Train with 250 rows for 42 epochs - Accuracy: 0.31
# Model (90) - Perceptron | Train with 250 rows for 47 epochs - Accuracy: 0.45
# Model (91) - Perceptron | Train with 250 rows for 52 epochs - Accuracy: 0.23
# Model (92) - Perceptron | Train with 250 rows for 57 epochs - Accuracy: 0.20
# Model (93) - Perceptron | Train with 250 rows for 62 epochs - Accuracy: 0.19
# Model (94) - Perceptron | Train with 250 rows for 67 epochs - Accuracy: 0.53
# Model (95) - Perceptron | Train with 250 rows for 72 epochs - Accuracy: 0.33
# Model (96) - Perceptron | Train with 250 rows for 77 epochs - Accuracy: 0.46
# Model (97) - Perceptron | Train with 250 rows for 82 epochs - Accuracy: 0.47
# Model (98) - Perceptron | Train with 250 rows for 87 epochs - Accuracy: 0.50
# Model (99) - Perceptron | Train with 250 rows for 92 epochs - Accuracy: 0.24
# Model (100) - Perceptron | Train with 250 rows for 97 epochs - Accuracy: 0.37
# Model (101) - Perceptron | Train with 300 rows for 2 epochs - Accuracy: 0.46
# Model (102) - Perceptron | Train with 300 rows for 7 epochs - Accuracy: 0.16
# Model (103) - Perceptron | Train with 300 rows for 12 epochs - Accuracy: 0.48
# Model (104) - Perceptron | Train with 300 rows for 17 epochs - Accuracy: 0.11
# Model (105) - Perceptron | Train with 300 rows for 22 epochs - Accuracy: 0.46
# Model (106) - Perceptron | Train with 300 rows for 27 epochs - Accuracy: 0.58
# Model (107) - Perceptron | Train with 300 rows for 32 epochs - Accuracy: 0.50
# Model (108) - Perceptron | Train with 300 rows for 37 epochs - Accuracy: 0.26
# Model (109) - Perceptron | Train with 300 rows for 42 epochs - Accuracy: 0.28
# Model (110) - Perceptron | Train with 300 rows for 47 epochs - Accuracy: 0.52
# Model (111) - Perceptron | Train with 300 rows for 52 epochs - Accuracy: 0.04
# Model (112) - Perceptron | Train with 300 rows for 57 epochs - Accuracy: 0.56
# Model (113) - Perceptron | Train with 300 rows for 62 epochs - Accuracy: 0.12
# Model (114) - Perceptron | Train with 300 rows for 67 epochs - Accuracy: 0.52
# Model (115) - Perceptron | Train with 300 rows for 72 epochs - Accuracy: 0.27
# Model (116) - Perceptron | Train with 300 rows for 77 epochs - Accuracy: 0.50
# Model (117) - Perceptron | Train with 300 rows for 82 epochs - Accuracy: 0.42
# Model (118) - Perceptron | Train with 300 rows for 87 epochs - Accuracy: 0.43
# Model (119) - Perceptron | Train with 300 rows for 92 epochs - Accuracy: 0.15
# Model (120) - Perceptron | Train with 300 rows for 97 epochs - Accuracy: 0.22
# Model (121) - Perceptron | Train with 350 rows for 2 epochs - Accuracy: 0.51
# Model (122) - Perceptron | Train with 350 rows for 7 epochs - Accuracy: 0.54
# Model (123) - Perceptron | Train with 350 rows for 12 epochs - Accuracy: 0.32
# Model (124) - Perceptron | Train with 350 rows for 17 epochs - Accuracy: 0.57
# Model (125) - Perceptron | Train with 350 rows for 22 epochs - Accuracy: 0.36
# Model (126) - Perceptron | Train with 350 rows for 27 epochs - Accuracy: 0.20
# Model (127) - Perceptron | Train with 350 rows for 32 epochs - Accuracy: 0.37
# Model (128) - Perceptron | Train with 350 rows for 37 epochs - Accuracy: 0.10
# Model (129) - Perceptron | Train with 350 rows for 42 epochs - Accuracy: 0.37
# Model (130) - Perceptron | Train with 350 rows for 47 epochs - Accuracy: 0.34
# Model (131) - Perceptron | Train with 350 rows for 52 epochs - Accuracy: 0.57
# Model (132) - Perceptron | Train with 350 rows for 57 epochs - Accuracy: 0.30
# Model (133) - Perceptron | Train with 350 rows for 62 epochs - Accuracy: 0.50
# Model (134) - Perceptron | Train with 350 rows for 67 epochs - Accuracy: 0.56
# Model (135) - Perceptron | Train with 350 rows for 72 epochs - Accuracy: 0.11
# Model (136) - Perceptron | Train with 350 rows for 77 epochs - Accuracy: 0.46
# Model (137) - Perceptron | Train with 350 rows for 82 epochs - Accuracy: 0.09
# Model (138) - Perceptron | Train with 350 rows for 87 epochs - Accuracy: 0.20
# Model (139) - Perceptron | Train with 350 rows for 92 epochs - Accuracy: 0.26
# Model (140) - Perceptron | Train with 350 rows for 97 epochs - Accuracy: 0.42
# Model (141) - Perceptron | Train with 400 rows for 2 epochs - Accuracy: 0.41
# Model (142) - Perceptron | Train with 400 rows for 7 epochs - Accuracy: 0.45
# Model (143) - Perceptron | Train with 400 rows for 12 epochs - Accuracy: 0.53
# Model (144) - Perceptron | Train with 400 rows for 17 epochs - Accuracy: 0.19
# Model (145) - Perceptron | Train with 400 rows for 22 epochs - Accuracy: 0.42
# Model (146) - Perceptron | Train with 400 rows for 27 epochs - Accuracy: 0.11
# Model (147) - Perceptron | Train with 400 rows for 32 epochs - Accuracy: 0.61
# Model (148) - Perceptron | Train with 400 rows for 37 epochs - Accuracy: 0.55
# Model (149) - Perceptron | Train with 400 rows for 42 epochs - Accuracy: 0.20
# Model (150) - Perceptron | Train with 400 rows for 47 epochs - Accuracy: 0.49
# Model (151) - Perceptron | Train with 400 rows for 52 epochs - Accuracy: 0.15
# Model (152) - Perceptron | Train with 400 rows for 57 epochs - Accuracy: 0.13
# Model (153) - Perceptron | Train with 400 rows for 62 epochs - Accuracy: 0.33
# Model (154) - Perceptron | Train with 400 rows for 67 epochs - Accuracy: 0.24
# Model (155) - Perceptron | Train with 400 rows for 72 epochs - Accuracy: 0.07
# Model (156) - Perceptron | Train with 400 rows for 77 epochs - Accuracy: 0.46
# Model (157) - Perceptron | Train with 400 rows for 82 epochs - Accuracy: 0.39
# Model (158) - Perceptron | Train with 400 rows for 87 epochs - Accuracy: 0.39
# Model (159) - Perceptron | Train with 400 rows for 92 epochs - Accuracy: 0.59
# Model (160) - Perceptron | Train with 400 rows for 97 epochs - Accuracy: 0.43
# Model (161) - Perceptron | Train with 450 rows for 2 epochs - Accuracy: 0.55
# Model (162) - Perceptron | Train with 450 rows for 7 epochs - Accuracy: 0.62
# Model (163) - Perceptron | Train with 450 rows for 12 epochs - Accuracy: 0.35
# Model (164) - Perceptron | Train with 450 rows for 17 epochs - Accuracy: 0.60
# Model (165) - Perceptron | Train with 450 rows for 22 epochs - Accuracy: 0.58
# Model (166) - Perceptron | Train with 450 rows for 27 epochs - Accuracy: 0.45
# Model (167) - Perceptron | Train with 450 rows for 32 epochs - Accuracy: 0.60
# Model (168) - Perceptron | Train with 450 rows for 37 epochs - Accuracy: 0.41
# Model (169) - Perceptron | Train with 450 rows for 42 epochs - Accuracy: 0.32
# Model (170) - Perceptron | Train with 450 rows for 47 epochs - Accuracy: 0.37
# Model (171) - Perceptron | Train with 450 rows for 52 epochs - Accuracy: 0.28
# Model (172) - Perceptron | Train with 450 rows for 57 epochs - Accuracy: 0.61
# Model (173) - Perceptron | Train with 450 rows for 62 epochs - Accuracy: 0.58
# Model (174) - Perceptron | Train with 450 rows for 67 epochs - Accuracy: 0.63
# Model (175) - Perceptron | Train with 450 rows for 72 epochs - Accuracy: 0.46
# Model (176) - Perceptron | Train with 450 rows for 77 epochs - Accuracy: 0.51
# Model (177) - Perceptron | Train with 450 rows for 82 epochs - Accuracy: 0.31
# Model (178) - Perceptron | Train with 450 rows for 87 epochs - Accuracy: 0.27
# Model (179) - Perceptron | Train with 450 rows for 92 epochs - Accuracy: 0.43
# Model (180) - Perceptron | Train with 450 rows for 97 epochs - Accuracy: 0.40
# Model (181) - Perceptron | Train with 500 rows for 2 epochs - Accuracy: 0.23
# Model (182) - Perceptron | Train with 500 rows for 7 epochs - Accuracy: 0.51
# Model (183) - Perceptron | Train with 500 rows for 12 epochs - Accuracy: 0.48
# Model (184) - Perceptron | Train with 500 rows for 17 epochs - Accuracy: 0.27
# Model (185) - Perceptron | Train with 500 rows for 22 epochs - Accuracy: 0.41
# Model (186) - Perceptron | Train with 500 rows for 27 epochs - Accuracy: 0.20
# Model (187) - Perceptron | Train with 500 rows for 32 epochs - Accuracy: 0.50
# Model (188) - Perceptron | Train with 500 rows for 37 epochs - Accuracy: 0.51
# Model (189) - Perceptron | Train with 500 rows for 42 epochs - Accuracy: 0.35
# Model (190) - Perceptron | Train with 500 rows for 47 epochs - Accuracy: 0.41
# Model (191) - Perceptron | Train with 500 rows for 52 epochs - Accuracy: 0.30
# Model (192) - Perceptron | Train with 500 rows for 57 epochs - Accuracy: 0.54
# Model (193) - Perceptron | Train with 500 rows for 62 epochs - Accuracy: 0.21
# Model (194) - Perceptron | Train with 500 rows for 67 epochs - Accuracy: 0.56
# Model (195) - Perceptron | Train with 500 rows for 72 epochs - Accuracy: 0.32
# Model (196) - Perceptron | Train with 500 rows for 77 epochs - Accuracy: 0.47
# Model (197) - Perceptron | Train with 500 rows for 82 epochs - Accuracy: 0.37
# Model (198) - Perceptron | Train with 500 rows for 87 epochs - Accuracy: 0.51
# Model (199) - Perceptron | Train with 500 rows for 92 epochs - Accuracy: 0.62
# Model (200) - Perceptron | Train with 500 rows for 97 epochs - Accuracy: 0.38
# Model (201) - Perceptron | Train with 550 rows for 2 epochs - Accuracy: 0.22
# Model (202) - Perceptron | Train with 550 rows for 7 epochs - Accuracy: 0.56
# Model (203) - Perceptron | Train with 550 rows for 12 epochs - Accuracy: 0.60
# Model (204) - Perceptron | Train with 550 rows for 17 epochs - Accuracy: 0.15
# Model (205) - Perceptron | Train with 550 rows for 22 epochs - Accuracy: 0.44
# Model (206) - Perceptron | Train with 550 rows for 27 epochs - Accuracy: 0.56
# Model (207) - Perceptron | Train with 550 rows for 32 epochs - Accuracy: 0.42
# Model (208) - Perceptron | Train with 550 rows for 37 epochs - Accuracy: 0.39
# Model (209) - Perceptron | Train with 550 rows for 42 epochs - Accuracy: 0.53
# Model (210) - Perceptron | Train with 550 rows for 47 epochs - Accuracy: 0.17
# Model (211) - Perceptron | Train with 550 rows for 52 epochs - Accuracy: 0.64
# Model (212) - Perceptron | Train with 550 rows for 57 epochs - Accuracy: 0.40
# Model (213) - Perceptron | Train with 550 rows for 62 epochs - Accuracy: 0.33
# Model (214) - Perceptron | Train with 550 rows for 67 epochs - Accuracy: 0.54
# Model (215) - Perceptron | Train with 550 rows for 72 epochs - Accuracy: 0.54
# Model (216) - Perceptron | Train with 550 rows for 77 epochs - Accuracy: 0.43
# Model (217) - Perceptron | Train with 550 rows for 82 epochs - Accuracy: 0.60
# Model (218) - Perceptron | Train with 550 rows for 87 epochs - Accuracy: 0.56
# Model (219) - Perceptron | Train with 550 rows for 92 epochs - Accuracy: 0.19
# Model (220) - Perceptron | Train with 550 rows for 97 epochs - Accuracy: 0.64
# Model (221) - Perceptron | Train with 600 rows for 2 epochs - Accuracy: 0.47
# Model (222) - Perceptron | Train with 600 rows for 7 epochs - Accuracy: 0.26
# Model (223) - Perceptron | Train with 600 rows for 12 epochs - Accuracy: 0.49
# Model (224) - Perceptron | Train with 600 rows for 17 epochs - Accuracy: 0.18
# Model (225) - Perceptron | Train with 600 rows for 22 epochs - Accuracy: 0.36
# Model (226) - Perceptron | Train with 600 rows for 27 epochs - Accuracy: 0.58
# Model (227) - Perceptron | Train with 600 rows for 32 epochs - Accuracy: 0.36
# Model (228) - Perceptron | Train with 600 rows for 37 epochs - Accuracy: 0.26
# Model (229) - Perceptron | Train with 600 rows for 42 epochs - Accuracy: 0.34
# Model (230) - Perceptron | Train with 600 rows for 47 epochs - Accuracy: 0.59
# Model (231) - Perceptron | Train with 600 rows for 52 epochs - Accuracy: 0.52
# Model (232) - Perceptron | Train with 600 rows for 57 epochs - Accuracy: 0.32
# Model (233) - Perceptron | Train with 600 rows for 62 epochs - Accuracy: 0.45
# Model (234) - Perceptron | Train with 600 rows for 67 epochs - Accuracy: 0.47
# Model (235) - Perceptron | Train with 600 rows for 72 epochs - Accuracy: 0.17
# Model (236) - Perceptron | Train with 600 rows for 77 epochs - Accuracy: 0.59
# Model (237) - Perceptron | Train with 600 rows for 82 epochs - Accuracy: 0.10
# Model (238) - Perceptron | Train with 600 rows for 87 epochs - Accuracy: 0.33
# Model (239) - Perceptron | Train with 600 rows for 92 epochs - Accuracy: 0.41
# Model (240) - Perceptron | Train with 600 rows for 97 epochs - Accuracy: 0.64
# Model (241) - Perceptron | Train with 650 rows for 2 epochs - Accuracy: 0.86
# Model (242) - Perceptron | Train with 650 rows for 7 epochs - Accuracy: 0.15
# Model (243) - Perceptron | Train with 650 rows for 12 epochs - Accuracy: 0.38
# Model (244) - Perceptron | Train with 650 rows for 17 epochs - Accuracy: 0.56
# Model (245) - Perceptron | Train with 650 rows for 22 epochs - Accuracy: 0.49
# Model (246) - Perceptron | Train with 650 rows for 27 epochs - Accuracy: 0.80
# Model (247) - Perceptron | Train with 650 rows for 32 epochs - Accuracy: 0.56
# Model (248) - Perceptron | Train with 650 rows for 37 epochs - Accuracy: 0.54
# Model (249) - Perceptron | Train with 650 rows for 42 epochs - Accuracy: 0.33
# Model (250) - Perceptron | Train with 650 rows for 47 epochs - Accuracy: 0.84
# Model (251) - Perceptron | Train with 650 rows for 52 epochs - Accuracy: 0.20
# Model (252) - Perceptron | Train with 650 rows for 57 epochs - Accuracy: 0.36
# Model (253) - Perceptron | Train with 650 rows for 62 epochs - Accuracy: 0.47
# Model (254) - Perceptron | Train with 650 rows for 67 epochs - Accuracy: 0.96
# Model (255) - Perceptron | Train with 650 rows for 72 epochs - Accuracy: 0.84
# Model (256) - Perceptron | Train with 650 rows for 77 epochs - Accuracy: 0.38
# Model (257) - Perceptron | Train with 650 rows for 82 epochs - Accuracy: 0.67
# Model (258) - Perceptron | Train with 650 rows for 87 epochs - Accuracy: 0.82
# Model (259) - Perceptron | Train with 650 rows for 92 epochs - Accuracy: 0.59
# Model (260) - Perceptron | Train with 650 rows for 97 epochs - Accuracy: 0.25
# Model (261) - Perceptron | Train with 700 rows for 2 epochs - Accuracy: 0.81
# Model (262) - Perceptron | Train with 700 rows for 7 epochs - Accuracy: 0.81
# Model (263) - Perceptron | Train with 700 rows for 12 epochs - Accuracy: 0.89
# Model (264) - Perceptron | Train with 700 rows for 17 epochs - Accuracy: 0.46
# Model (265) - Perceptron | Train with 700 rows for 22 epochs - Accuracy: 0.40
# Model (266) - Perceptron | Train with 700 rows for 27 epochs - Accuracy: 0.76
# Model (267) - Perceptron | Train with 700 rows for 32 epochs - Accuracy: 0.61
# Model (268) - Perceptron | Train with 700 rows for 37 epochs - Accuracy: 0.83
# Model (269) - Perceptron | Train with 700 rows for 42 epochs - Accuracy: 0.35
# Model (270) - Perceptron | Train with 700 rows for 47 epochs - Accuracy: 0.79
# Model (271) - Perceptron | Train with 700 rows for 52 epochs - Accuracy: 0.28
# Model (272) - Perceptron | Train with 700 rows for 57 epochs - Accuracy: 0.77
# Model (273) - Perceptron | Train with 700 rows for 62 epochs - Accuracy: 0.61
# Model (274) - Perceptron | Train with 700 rows for 67 epochs - Accuracy: 0.70
# Model (275) - Perceptron | Train with 700 rows for 72 epochs - Accuracy: 0.75
# Model (276) - Perceptron | Train with 700 rows for 77 epochs - Accuracy: 0.82
# Model (277) - Perceptron | Train with 700 rows for 82 epochs - Accuracy: 0.57
# Model (278) - Perceptron | Train with 700 rows for 87 epochs - Accuracy: 0.43
# Model (279) - Perceptron | Train with 700 rows for 92 epochs - Accuracy: 0.28
# Model (239) - Adaline | Train with 600 rows for 92 epochs - Accuracy: 0.86
# Model (240) - Adaline | Train with 600 rows for 97 epochs - Accuracy: 0.86
# Model (241) - Adaline | Train with 650 rows for 2 epochs - Accuracy: 0.93
# Model (242) - Adaline | Train with 650 rows for 7 epochs - Accuracy: 0.96
# Model (243) - Adaline | Train with 650 rows for 12 epochs - Accuracy: 0.95
# Model (244) - Adaline | Train with 650 rows for 17 epochs - Accuracy: 0.94
# Model (245) - Adaline | Train with 650 rows for 22 epochs - Accuracy: 0.93
# Model (246) - Adaline | Train with 650 rows for 27 epochs - Accuracy: 0.91
# Model (247) - Adaline | Train with 650 rows for 32 epochs - Accuracy: 0.89
# Model (248) - Adaline | Train with 650 rows for 37 epochs - Accuracy: 0.88
# Model (249) - Adaline | Train with 650 rows for 42 epochs - Accuracy: 0.87
# Model (250) - Adaline | Train with 650 rows for 47 epochs - Accuracy: 0.86
# Model (251) - Adaline | Train with 650 rows for 52 epochs - Accuracy: 0.86
# Model (252) - Adaline | Train with 650 rows for 57 epochs - Accuracy: 0.86
# Model (253) - Adaline | Train with 650 rows for 62 epochs - Accuracy: 0.85
# Model (254) - Adaline | Train with 650 rows for 67 epochs - Accuracy: 0.85
# Model (255) - Adaline | Train with 650 rows for 72 epochs - Accuracy: 0.84
# Model (256) - Adaline | Train with 650 rows for 77 epochs - Accuracy: 0.84
# Model (257) - Adaline | Train with 650 rows for 82 epochs - Accuracy: 0.83
# Model (258) - Adaline | Train with 650 rows for 87 epochs - Accuracy: 0.83
# Model (259) - Adaline | Train with 650 rows for 92 epochs - Accuracy: 0.83
# Model (260) - Adaline | Train with 650 rows for 97 epochs - Accuracy: 0.83
# Model (261) - Adaline | Train with 700 rows for 2 epochs - Accuracy: 0.90
# Model (262) - Adaline | Train with 700 rows for 7 epochs - Accuracy: 0.89
# Model (263) - Adaline | Train with 700 rows for 12 epochs - Accuracy: 0.85
# Model (264) - Adaline | Train with 700 rows for 17 epochs - Accuracy: 0.79
# Model (265) - Adaline | Train with 700 rows for 22 epochs - Accuracy: 0.75
# Model (266) - Adaline | Train with 700 rows for 27 epochs - Accuracy: 0.72
# Model (267) - Adaline | Train with 700 rows for 32 epochs - Accuracy: 0.71
# Model (268) - Adaline | Train with 700 rows for 37 epochs - Accuracy: 0.70
# Model (269) - Adaline | Train with 700 rows for 42 epochs - Accuracy: 0.69
# Model (270) - Adaline | Train with 700 rows for 47 epochs - Accuracy: 0.69
# Model (271) - Adaline | Train with 700 rows for 52 epochs - Accuracy: 0.69
# Model (272) - Adaline | Train with 700 rows for 57 epochs - Accuracy: 0.68
# Model (273) - Adaline | Train with 700 rows for 62 epochs - Accuracy: 0.68
# Model (274) - Adaline | Train with 700 rows for 67 epochs - Accuracy: 0.68
# Model (275) - Adaline | Train with 700 rows for 72 epochs - Accuracy: 0.68
# Model (276) - Adaline | Train with 700 rows for 77 epochs - Accuracy: 0.68
# Model (277) - Adaline | Train with 700 rows for 82 epochs - Accuracy: 0.68
# Model (278) - Adaline | Train with 700 rows for 87 epochs - Accuracy: 0.68
# Model (279) - Adaline | Train with 700 rows for 92 epochs - Accuracy: 0.68
# Model (280) - Adaline | Train with 700 rows for 97 epochs - Accuracy: 0.68
# Model (1) - Logisticregression | Train with 50 rows for 2 epochs - Accuracy: 0.66
# Model (2) - Logisticregression | Train with 50 rows for 7 epochs - Accuracy: 0.71
# Model (3) - Logisticregression | Train with 50 rows for 12 epochs - Accuracy: 0.72
# Model (4) - Logisticregression | Train with 50 rows for 17 epochs - Accuracy: 0.74
# Model (5) - Logisticregression | Train with 50 rows for 22 epochs - Accuracy: 0.75
# Model (6) - Logisticregression | Train with 50 rows for 27 epochs - Accuracy: 0.76
# Model (7) - Logisticregression | Train with 50 rows for 32 epochs - Accuracy: 0.76
# Model (8) - Logisticregression | Train with 50 rows for 37 epochs - Accuracy: 0.77
# Model (9) - Logisticregression | Train with 50 rows for 42 epochs - Accuracy: 0.78
# Model (10) - Logisticregression | Train with 50 rows for 47 epochs - Accuracy: 0.78
# Model (11) - Logisticregression | Train with 50 rows for 52 epochs - Accuracy: 0.78
# Model (12) - Logisticregression | Train with 50 rows for 57 epochs - Accuracy: 0.78
# Model (13) - Logisticregression | Train with 50 rows for 62 epochs - Accuracy: 0.78
# Model (14) - Logisticregression | Train with 50 rows for 67 epochs - Accuracy: 0.77
# Model (15) - Logisticregression | Train with 50 rows for 72 epochs - Accuracy: 0.76
# Model (16) - Logisticregression | Train with 50 rows for 77 epochs - Accuracy: 0.77
# Model (17) - Logisticregression | Train with 50 rows for 82 epochs - Accuracy: 0.77
# Model (18) - Logisticregression | Train with 50 rows for 87 epochs - Accuracy: 0.76
# Model (19) - Logisticregression | Train with 50 rows for 92 epochs - Accuracy: 0.76
# Model (20) - Logisticregression | Train with 50 rows for 97 epochs - Accuracy: 0.76
# Model (21) - Logisticregression | Train with 100 rows for 2 epochs - Accuracy: 0.67
# Model (22) - Logisticregression | Train with 100 rows for 7 epochs - Accuracy: 0.73
# Model (23) - Logisticregression | Train with 100 rows for 12 epochs - Accuracy: 0.79
# Model (24) - Logisticregression | Train with 100 rows for 17 epochs - Accuracy: 0.84
# Model (25) - Logisticregression | Train with 100 rows for 22 epochs - Accuracy: 0.87
# Model (26) - Logisticregression | Train with 100 rows for 27 epochs - Accuracy: 0.87
# Model (27) - Logisticregression | Train with 100 rows for 32 epochs - Accuracy: 0.87
# Model (28) - Logisticregression | Train with 100 rows for 37 epochs - Accuracy: 0.88
# Model (29) - Logisticregression | Train with 100 rows for 42 epochs - Accuracy: 0.87
# Model (30) - Logisticregression | Train with 100 rows for 47 epochs - Accuracy: 0.85
# Model (31) - Logisticregression | Train with 100 rows for 52 epochs - Accuracy: 0.84
# Model (32) - Logisticregression | Train with 100 rows for 57 epochs - Accuracy: 0.84
# Model (33) - Logisticregression | Train with 100 rows for 62 epochs - Accuracy: 0.83
# Model (34) - Logisticregression | Train with 100 rows for 67 epochs - Accuracy: 0.83
# Model (35) - Logisticregression | Train with 100 rows for 72 epochs - Accuracy: 0.83
# Model (36) - Logisticregression | Train with 100 rows for 77 epochs - Accuracy: 0.82
# Model (37) - Logisticregression | Train with 100 rows for 82 epochs - Accuracy: 0.82
# Model (38) - Logisticregression | Train with 100 rows for 87 epochs - Accuracy: 0.81
# Model (39) - Logisticregression | Train with 100 rows for 92 epochs - Accuracy: 0.81
# Model (40) - Logisticregression | Train with 100 rows for 97 epochs - Accuracy: 0.81
# Model (41) - Logisticregression | Train with 150 rows for 2 epochs - Accuracy: 0.69
# Model (42) - Logisticregression | Train with 150 rows for 7 epochs - Accuracy: 0.75
# Model (43) - Logisticregression | Train with 150 rows for 12 epochs - Accuracy: 0.80
# Model (44) - Logisticregression | Train with 150 rows for 17 epochs - Accuracy: 0.85
# Model (45) - Logisticregression | Train with 150 rows for 22 epochs - Accuracy: 0.87
# Model (46) - Logisticregression | Train with 150 rows for 27 epochs - Accuracy: 0.88
# Model (47) - Logisticregression | Train with 150 rows for 32 epochs - Accuracy: 0.89
# Model (48) - Logisticregression | Train with 150 rows for 37 epochs - Accuracy: 0.90
# Model (49) - Logisticregression | Train with 150 rows for 42 epochs - Accuracy: 0.90
# Model (50) - Logisticregression | Train with 150 rows for 47 epochs - Accuracy: 0.90
# Model (51) - Logisticregression | Train with 150 rows for 52 epochs - Accuracy: 0.90
# Model (52) - Logisticregression | Train with 150 rows for 57 epochs - Accuracy: 0.90
# Model (53) - Logisticregression | Train with 150 rows for 62 epochs - Accuracy: 0.90
# Model (54) - Logisticregression | Train with 150 rows for 67 epochs - Accuracy: 0.90
# Model (55) - Logisticregression | Train with 150 rows for 72 epochs - Accuracy: 0.90
# Model (56) - Logisticregression | Train with 150 rows for 77 epochs - Accuracy: 0.90
# Model (57) - Logisticregression | Train with 150 rows for 82 epochs - Accuracy: 0.91
# Model (58) - Logisticregression | Train with 150 rows for 87 epochs - Accuracy: 0.91
# Model (59) - Logisticregression | Train with 150 rows for 92 epochs - Accuracy: 0.91
# Model (60) - Logisticregression | Train with 150 rows for 97 epochs - Accuracy: 0.91
# Model (61) - Logisticregression | Train with 200 rows for 2 epochs - Accuracy: 0.72
# Model (62) - Logisticregression | Train with 200 rows for 7 epochs - Accuracy: 0.83
# Model (63) - Logisticregression | Train with 200 rows for 12 epochs - Accuracy: 0.89
# Model (64) - Logisticregression | Train with 200 rows for 17 epochs - Accuracy: 0.90
# ...
# Model (210) - Logisticregression | Train with 550 rows for 47 epochs - Accuracy: 0.93
# Model (211) - Logisticregression | Train with 550 rows for 52 epochs - Accuracy: 0.93
# Model (212) - Logisticregression | Train with 550 rows for 57 epochs - Accuracy: 0.93
# Model (213) - Logisticregression | Train with 550 rows for 62 epochs - Accuracy: 0.93
# Model (214) - Logisticregression | Train with 550 rows for 67 epochs - Accuracy: 0.93
# Model (215) - Logisticregression | Train with 550 rows for 72 epochs - Accuracy: 0.93
# Model (216) - Logisticregression | Train with 550 rows for 77 epochs - Accuracy: 0.93
# Model (217) - Logisticregression | Train with 550 rows for 82 epochs - Accuracy: 0.92
# Model (218) - Logisticregression | Train with 550 rows for 87 epochs - Accuracy: 0.92
# Model (219) - Logisticregression | Train with 550 rows for 92 epochs - Accuracy: 0.92
# Model (220) - Logisticregression | Train with 550 rows for 97 epochs - Accuracy: 0.92
# Model (221) - Logisticregression | Train with 600 rows for 2 epochs - Accuracy: 0.86
# Model (222) - Logisticregression | Train with 600 rows for 7 epochs - Accuracy: 0.94
# Model (223) - Logisticregression | Train with 600 rows for 12 epochs - Accuracy: 0.94
# Model (224) - Logisticregression | Train with 600 rows for 17 epochs - Accuracy: 0.95
# Model (225) - Logisticregression | Train with 600 rows for 22 epochs - Accuracy: 0.95
# Model (226) - Logisticregression | Train with 600 rows for 27 epochs - Accuracy: 0.95
# Model (227) - Logisticregression | Train with 600 rows for 32 epochs - Accuracy: 0.95
# Model (228) - Logisticregression | Train with 600 rows for 37 epochs - Accuracy: 0.94
# Model (229) - Logisticregression | Train with 600 rows for 42 epochs - Accuracy: 0.94
# Model (230) - Logisticregression | Train with 600 rows for 47 epochs - Accuracy: 0.94
# Model (231) - Logisticregression | Train with 600 rows for 52 epochs - Accuracy: 0.94
# Model (232) - Logisticregression | Train with 600 rows for 57 epochs - Accuracy: 0.93
# Model (233) - Logisticregression | Train with 600 rows for 62 epochs - Accuracy: 0.93
# Model (234) - Logisticregression | Train with 600 rows for 67 epochs - Accuracy: 0.93
# Model (235) - Logisticregression | Train with 600 rows for 72 epochs - Accuracy: 0.93
# Model (236) - Logisticregression | Train with 600 rows for 77 epochs - Accuracy: 0.93
# Model (237) - Logisticregression | Train with 600 rows for 82 epochs - Accuracy: 0.93
# Model (238) - Logisticregression | Train with 600 rows for 87 epochs - Accuracy: 0.93
# Model (239) - Logisticregression | Train with 600 rows for 92 epochs - Accuracy: 0.93
# Model (240) - Logisticregression | Train with 600 rows for 97 epochs - Accuracy: 0.93
# Model (241) - Logisticregression | Train with 650 rows for 2 epochs - Accuracy: 0.88
# Model (242) - Logisticregression | Train with 650 rows for 7 epochs - Accuracy: 0.95
# Model (243) - Logisticregression | Train with 650 rows for 12 epochs - Accuracy: 0.96
# Model (244) - Logisticregression | Train with 650 rows for 17 epochs - Accuracy: 0.96
# Model (245) - Logisticregression | Train with 650 rows for 22 epochs - Accuracy: 0.96
# Model (246) - Logisticregression | Train with 650 rows for 27 epochs - Accuracy: 0.96
# Model (247) - Logisticregression | Train with 650 rows for 32 epochs - Accuracy: 0.96
# Model (248) - Logisticregression | Train with 650 rows for 37 epochs - Accuracy: 0.96
# Model (249) - Logisticregression | Train with 650 rows for 42 epochs - Accuracy: 0.96
# Model (250) - Logisticregression | Train with 650 rows for 47 epochs - Accuracy: 0.95
# Model (251) - Logisticregression | Train with 650 rows for 52 epochs - Accuracy: 0.94
# Model (252) - Logisticregression | Train with 650 rows for 57 epochs - Accuracy: 0.94
# Model (253) - Logisticregression | Train with 650 rows for 62 epochs - Accuracy: 0.93
# Model (254) - Logisticregression | Train with 650 rows for 67 epochs - Accuracy: 0.93
# Model (255) - Logisticregression | Train with 650 rows for 72 epochs - Accuracy: 0.94
# Model (256) - Logisticregression | Train with 650 rows for 77 epochs - Accuracy: 0.93
# Model (257) - Logisticregression | Train with 650 rows for 82 epochs - Accuracy: 0.94
# Model (258) - Logisticregression | Train with 650 rows for 87 epochs - Accuracy: 0.94
# Model (259) - Logisticregression | Train with 650 rows for 92 epochs - Accuracy: 0.93
# Model (260) - Logisticregression | Train with 650 rows for 97 epochs - Accuracy: 0.93
# Model (261) - Logisticregression | Train with 700 rows for 2 epochs - Accuracy: 0.86
# Model (262) - Logisticregression | Train with 700 rows for 7 epochs - Accuracy: 0.91
# Model (263) - Logisticregression | Train with 700 rows for 12 epochs - Accuracy: 0.90
# Model (264) - Logisticregression | Train with 700 rows for 17 epochs - Accuracy: 0.89
# Model (265) - Logisticregression | Train with 700 rows for 22 epochs - Accuracy: 0.89
# Model (266) - Logisticregression | Train with 700 rows for 27 epochs - Accuracy: 0.89
# Model (267) - Logisticregression | Train with 700 rows for 32 epochs - Accuracy: 0.88
# Model (268) - Logisticregression | Train with 700 rows for 37 epochs - Accuracy: 0.85
# Model (269) - Logisticregression | Train with 700 rows for 42 epochs - Accuracy: 0.85
# Model (270) - Logisticregression | Train with 700 rows for 47 epochs - Accuracy: 0.85
# Model (271) - Logisticregression | Train with 700 rows for 52 epochs - Accuracy: 0.84
# Model (272) - Logisticregression | Train with 700 rows for 57 epochs - Accuracy: 0.83
# Model (273) - Logisticregression | Train with 700 rows for 62 epochs - Accuracy: 0.82
# Model (274) - Logisticregression | Train with 700 rows for 67 epochs - Accuracy: 0.80
# Model (275) - Logisticregression | Train with 700 rows for 72 epochs - Accuracy: 0.78
# Model (276) - Logisticregression | Train with 700 rows for 77 epochs - Accuracy: 0.78
# Model (277) - Logisticregression | Train with 700 rows for 82 epochs - Accuracy: 0.77
# Model (278) - Logisticregression | Train with 700 rows for 87 epochs - Accuracy: 0.76
# Model (279) - Logisticregression | Train with 700 rows for 92 epochs - Accuracy: 0.75
# Model (280) - Logisticregression | Train with 700 rows for 97 epochs - Accuracy: 0.74
#
# Final Accuracy Matrix (3x14x20):
# [[[0.69040248 0.51393189 0.39009288 0.48606811 0.44891641 0.33436533
#    0.42724458 0.42105263 0.42724458 0.25386997 0.39009288 0.47678019
#    0.36532508 0.14860681 0.52941176 0.25077399 0.36532508 0.30650155
#    0.19195046 0.39628483]
#   [0.48297214 0.36842105 0.23529412 0.57894737 0.27863777 0.11455108
#    0.29721362 0.30340557 0.40557276 0.29411765 0.52941176 0.35294118
#    0.26625387 0.47678019 0.40247678 0.49535604 0.09907121 0.59442724
#    0.56965944 0.37770898]
#   [0.41795666 0.40866873 0.48606811 0.34674923 0.30650155 0.52941176
#    0.37151703 0.40866873 0.10526316 0.46130031 0.36532508 0.20743034
#    0.22291022 0.40247678 0.46439628 0.39628483 0.22291022 0.28173375
#    0.3250774  0.28173375]
#   [0.40557276 0.40866873 0.13312693 0.27863777 0.13312693 0.42414861
#    0.52941176 0.21052632 0.36842105 0.34055728 0.41795666 0.27244582
#    0.43653251 0.62229102 0.56346749 0.21981424 0.51702786 0.3498452
#    0.42414861 0.37151703]
#   [0.48606811 0.38080495 0.51083591 0.34674923 0.47368421 0.32198142
#    0.47368421 0.374613   0.3126935  0.45201238 0.22910217 0.19814241
#    0.95975232 0.95665635 0.95665635 0.9504644  0.94117647 0.9380805
#    0.93498452 0.93498452 0.9380805  0.93498452 0.9380805  0.9380805
#    0.92879257 0.92569659]
#   [0.86377709 0.91021672 0.90402477 0.89164087 0.89164087 0.88544892
#    0.87616099 0.85448916 0.84829721 0.84520124 0.84210526 0.82972136
#    0.82043344 0.79566563 0.78328173 0.78018576 0.77089783 0.76160991
#    0.74922601 0.73993808]]]

# %% [markdown]
# ### Performance visualization
#
# Plot the performance measure for all classifiers (accuracy on the test set; use the result array from above) of all the $280$ variants for each classifier in a total of three heatmaps using, for example `seaborn` or `matplotlib` directly.
#
# The color should represent the accuracy on the test set, and the x and y axes should represent the number of epochs and the dataset size, respectively.
# Which one is x and which one is y is up to you to decide. Look in the example output at the top of the assignment for inspiration for how the plot could look like and how it could be labeled nicely. (But use the correct numbers corresponding to your dataset sizes and number of epochs.)

# %%
# Insert your code below
# ======================

model_names = ["Perceptron", "Adaline", "LogisticRegression"]
epoch_values = [2 + 5 * j for j in range(20)]  
row_values = [50 + 50 * i for i in range(14)] 
accuracy_data = accuracy_matrix[model_idx]

for model_idx, model_name in enumerate(model_names):
    plt.figure(figsize=(12, 6))
    
    accuracy_data = accuracy_matrix[model_idx]  # Shape (14, 20)
    sns.heatmap(accuracy_data, annot=True, fmt=".2f", xticklabels=epoch_values, yticklabels=row_values, cmap="viridis")

    plt.xlabel("Epochs")
    plt.ylabel("Training Rows")
    plt.title(f"Accuracy Heatmap for {model_name}")
    plt.show()

# %% [markdown]
# # Part V: Some more plotting
#
# For the following cell to execute you need to have the variable `X_test_scaled` with all samples of the test set and the variable `y_test` with the corresponding labels.
# Complete at least up until Part III. Executing the cell will plot something.
#
# 1. Add code comments explaining what the lines are doing
# 2. What is the purpose of the plot?
# 3. Describe all components of the subplot and then comment in general on the entire plot. What does it show? What does it not show?

# %%
# Train and a logistic regression model with 300 epochs and learning rate 0.0001
clf = LogisticRegression(eta = 0.0001, epochs = 300, minibatches=1, random_seed=42)
clf.fit(X_test_scaled, y_test)

fig, axes = plt.subplots(8, 8, figsize=(30, 30))
for i in range(0, 8):
    for j in range(0, 8):
        feature_1 = i
        feature_2 = j
        ax = axes[i, j]

        ax.set_xlabel(f"Feature {feature_1}")
        ax.set_ylabel(f"Feature {feature_2}")

        mins = X_test_scaled.min(axis=0)
        maxs = X_test_scaled.max(axis=0)

        x0 = np.linspace(mins[feature_1], maxs[feature_1], 100)
        x1 = np.linspace(mins[feature_2], maxs[feature_2], 100)

        X0, X1 = np.meshgrid(x0, x1)
        X_two_features = np.c_[X0.ravel(), X1.ravel()]
        X_plot = np.zeros(shape=(X_two_features.shape[0], X_test_scaled.shape[1]))

        X_plot[:, feature_1] = X_two_features[:, 0]
        X_plot[:, feature_2] = X_two_features[:, 1]

        y_pred = clf.predict_proba(X_plot)
        Z = y_pred.reshape(X0.shape)

        ax.pcolor(X0, X1, Z)
        ax.contour(X0, X1, Z, levels=[0.5], colors='k')
        ax.scatter(X_test_scaled[y_test == 0, feature_1], X_test_scaled[y_test == 0, feature_2], color="b", marker="^", s=50, facecolors="none")
        ax.scatter(X_test_scaled[y_test == 1, feature_1], X_test_scaled[y_test == 1, feature_2], color="y", marker="o", s=50, facecolors="none")

fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Train and a logistic regression model with 300 epochs and learning rate 0.0001
#       2 clf = LogisticRegression(eta = 0.0001, epochs = 300, minibatches=1, random_seed=42)
# ----> 3 clf.fit(X_test_scaled, y_test)
#       5 fig, axes = plt.subplots(8, 8, figsize=(30, 30))
#       6 for i in range(0, 8):
#
# File ~/anaconda3/envs/dat200_env/lib/python3.10/site-packages/mlxtend/_base/_classifier.py:81, in _Classifier.fit(self, X, y, init_params)
#      79     self._rgen = np.random.RandomState(self.random_seed)
#      80 self._init_time = time()
# ---> 81 self._fit(X=X, y=y, init_params=init_params)
#      82 self._is_fitted = True
#      83 return self
#
# File ~/anaconda3/envs/dat200_env/lib/python3.10/site-packages/mlxtend/classifier/logistic_regression.py:120, in LogisticRegression._fit(self, X, y, init_params)
#     116 for i in range(self.epochs):
#     117     for idx in self._yield_minibatches_idx(
#     118         rgen=rgen, n_batches=self.minibatches, data_ary=y, shuffle=True
#     119     ):
# --> 120         y_val = self._forward(X[idx])
#     121         grad_loss_wrt_w, grad_loss_wrt_b = self._backward(
#     122             X[idx], y_true=y[idx], y_probas=y_val
#     123         )
#     125         l2_reg = self.l2_lambda * self.w_
#
# File ~/anaconda3/envs/dat200_env/lib/python3.10/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/dat200_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/dat200_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([173, 132, 197,   9, 104, 119, 256, 158, 226, 312,\n       ...\n        87, 214, 121, 322,  20, 188,  71, 106, 270, 102],\n      dtype='int64', length=323)] are in the [columns]"

# %% [markdown]
# ## Part VI: Additional discussion
#
# ### Part I:
# 1. What kind of plots did you use to visualize the raw data, and why did you choose these types of plots?
#
# ### Part II:
# 1. What happens if we don't shuffle the training data before training the classifiers like in Part IV?
# 2. How could you do the same train/test split (Point 1.-4.) using scikit-learn?
#
# ### Part IV:
# 1. How does increasing the dataset size affect the performance of the logistic regression model? Provide a summary of your findings.
# 2. Describe the relationship between the number of epochs and model accuracy
# 3. Which classifier is much slower to train and why do you think that is?
# 4. One classifier shows strong fluctuations in accuracy for different dataset sizes and number of epochs. Which one is it and why do you think this happens?
